# %% [markdown]
# # DATA EXPLANATORY ANALYSIS FOR CREDIT CARD - CASE STUDY 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
Customer_acquisition=pd.read_csv('C:/Users/rhythm/Desktop/Data Analytics/python upload projects/Python Foundation Case Study 2 - Credit Card Case Study/Case Study 2 - Credit Card Case Study/Customer Acqusition.csv')

# %%
Customer_acquisition.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA  Silver  100000.0      C2   Salaried_MNC

# %%
Repayment=pd.read_csv('C:/Users/rhythm/Desktop/Data Analytics/python upload projects/Python Foundation Case Study 2 - Credit Card Case Study/Case Study 2 - Credit Card Case Study/Repayment.csv', usecols = ["Customer","Month","Amount"])

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02

# %%
Spend=pd.read_csv('C:/Users/rhythm/Desktop/Data Analytics/python upload projects/Python Foundation Case Study 2 - Credit Card Case Study/Case Study 2 - Credit Card Case Study/spend.csv')

# %%
Spend.head(2)
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13

# %%
Repayment.isnull().sum()
# Out:
# Customer    23
# Month       23
# Amount      23
# dtype: int64

# %%
Repayment.dropna(inplace=True)

# %%
Repayment.isnull().sum()
# Out:
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %% [markdown]
# ## 1a

# %%
mean_age =Customer_acquisition["Age"].mean()

# %%
print("The mean of Age is : ",mean_age)
# Out:
# The mean of Age is :  46.49

# %%
Customer_acquisition.loc[Customer_acquisition["Age"] < 18,"Age"] = Customer_acquisition["Age"].mean()

# %%
Customer_acquisition.head(14)
# Out:
#     No Customer    Age       City   Product     Limit Company        Segment
# 0    1       A1  76.00  BANGALORE      Gold  500000.0      C1  Self Employed
# 1    2       A2  71.00   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2    3       A3  34.00     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3    4       A4  47.00     BOMBAY  Platimum   10001.0      C4           Govt
# 4    5       A5  56.00  BANGALORE  Platimum   10002.0      C5  Normal Salary
# 5    6       A6  70.00      DELHI    Silver  100000.0      C6  Self Employed
# 6    7       A7  26.00     COCHIN    Silver  100001.0      C7   Salaried_MNC
# 7    8       A8  67.00      PATNA    Silver  100002.0      C8   Salaried_Pvt
# 8    9       A9  79.00    CHENNAI    Silver  100003.0      C9           Govt
# 9   10      A10  54.00   CALCUTTA      Gold  500000.0     C10  Normal Salary
# 10  11      A11  35.00     COCHIN      Gold  500000.0     C11  Normal Salary
# ...

# %% [markdown]
# ## 1b

# %%
cust_spend = pd.merge(left=Customer_acquisition,right=Spend,on="Customer",how="inner")

# %%
cust_spend.head(2)
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount
# 0       1  12-Jan-04  JEWELLERY  485470.80
# 1       2   3-Jan-04      PETRO  410556.13

# %%
cust_spend[cust_spend["Amount"] > cust_spend['Limit']]
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 18      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 19      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 20      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 21      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 22      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# ...   ...      ...   ...         ...       ...       ...     ...
# 1486   87      A87  27.0    CALCUTTA    Silver  100003.0     C10
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month          Type     Amount
# 18     Salaried_MNC     104   3-Jan-04        RENTAL  199554.72
# ...

# %%
cust_spend.loc[cust_spend["Amount"] > cust_spend["Limit"],"Amount"] = (50 * cust_spend["Limit"]).div(100)

# %%
cust_spend[cust_spend["Amount"] > cust_spend['Limit']]
# Out:
# Empty DataFrame
# Columns: [No, Customer, Age, City, Product, Limit, Company, Segment, Sl No:, Month, Type, Amount]
# Index: []

# %% [markdown]
# ## 1c

# %%
cust_repay = pd.merge(left=Repayment,right=Customer_acquisition,on="Customer",how="inner")

# %%
cust_repay.head(2)
# Out:
#   Customer      Month     Amount  No   Age       City Product     Limit  \
# 0       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold  500000.0
# 1       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold  500000.0
#
#   Company        Segment
# 0      C1  Self Employed
# 1      C1  Self Employed

# %%
cust_repay[cust_repay["Amount"] > cust_repay["Limit"]]
# Out:
#      Customer      Month     Amount  No   Age    City Product     Limit  \
# 18         A8   5-Feb-04  156913.59   8  67.0   PATNA  Silver  100002.0
# 19         A8  12-Jan-04  350999.98   8  67.0   PATNA  Silver  100002.0
# 20         A8  31-Mar-06  155642.95   8  67.0   PATNA  Silver  100002.0
# 21         A8   9-May-05  145457.38   8  67.0   PATNA  Silver  100002.0
# 22         A8   8-May-06  361184.89   8  67.0   PATNA  Silver  100002.0
# ...       ...        ...        ...  ..   ...     ...     ...       ...
# 1494       A7   6-May-06  400375.97   7  26.0  COCHIN  Silver  100001.0
# 1496       A7   3-Dec-05  429700.12   7  26.0  COCHIN  Silver  100001.0
# 1497       A7  23-Feb-05  344628.72   7  26.0  COCHIN  Silver  100001.0
# 1498       A7  31-Mar-06  336264.37   7  26.0  COCHIN  Silver  100001.0
# 1499       A7   3-Jan-04  473662.61   7  26.0  COCHIN  Silver  100001.0
#
#      Company       Segment
# 18        C8  Salaried_Pvt
# 19        C8  Salaried_Pvt
# ...

# %%
cust_repay.loc[cust_repay["Amount"] > cust_repay["Limit"],"Amount"] = cust_repay["Limit"]

# %%
cust_repay[cust_repay["Amount"] > cust_repay["Limit"]]
# Out:
# Empty DataFrame
# Columns: [Customer, Month, Amount, No, Age, City, Product, Limit, Company, Segment]
# Index: []

# %% [markdown]
# # 2a

# %%
distinct_cust = Customer_acquisition["Customer"].nunique()

# %%
print("No. of distinct customers are : ",distinct_cust)
# Out:
# No. of distinct customers are :  100

# %% [markdown]
# ## 2b

# %%
Customer_acquisition["Segment"].value_counts()
# Out:
# Segment
# Govt             29
# Self Employed    23
# Normal Salary    22
# Salaried_MNC     13
# Salaried_Pvt     13
# Name: count, dtype: int64

# %%
print("We can see from the above data that no. of distinct categories are"+' ' + '5')
# Out:
# We can see from the above data that no. of distinct categories are 5

# %% [markdown]
# # 2c

# %%
Spend.head(2)
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13

# %%
Spend['Month'] = pd.to_datetime(Spend['Month'])
# Out:
# C:\Users\rhythm\AppData\Local\Temp\ipykernel_6296\2311455342.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Spend['Month'] = pd.to_datetime(Spend['Month'])

# %%
Spend.head(2)
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1 2004-01-12  JEWELLERY  485470.80
# 1       2       A1 2004-01-03      PETRO  410556.13

# %%
Spend['Monthly'] = Spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Spend['Yearly'] = Spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
Spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount  Monthly Yearly
# 0       1       A1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       2       A1 2004-01-03      PETRO  410556.13  January   2004
# 2       3       A1 2004-01-15    CLOTHES   23740.46  January   2004
# 3       4       A1 2004-01-25       FOOD  484342.47  January   2004
# 4       5       A1 2005-01-17     CAMERA  369694.07  January   2005

# %%
Spend.dtypes
# Out:
# Sl No:               int64
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# Monthly             object
# Yearly              object
# dtype: object

# %%
Spend.pivot_table(index=('Yearly','Monthly'),values='Amount',aggfunc= 'mean').round(2).reset_index()
# Out:
#    Yearly    Monthly     Amount
# 0    2004      April  235272.04
# 1    2004   February  221215.27
# 2    2004    January  251712.07
# 3    2004      March  232146.12
# 4    2004        May  217539.24
# 5    2004   November  270486.40
# 6    2004  September  310923.38
# 7    2005      April  252181.33
# 8    2005     August  233734.63
# 9    2005   December  147503.06
# 10   2005   February  229802.28
# 11   2005    January  292741.37
# 12   2005       July  229116.66
# 13   2005       June  262688.11
# 14   2005        May  245696.52
# 15   2005   November  286143.32
# 16   2005    October  194568.64
# 17   2005  September  188666.20
# 18   2006      April  232468.97
# 19   2006     August  240699.72
# 20   2006   December  270470.98
# 21   2006   February  253858.26
# 22   2006    January  282058.01
# 23   2006       July  287505.10
# 24   2006       June  177252.39
# 25   2006      March  247166.08
# 26   2006        May  236162.74
# 27   2006   November  182841.29
# ...

# %% [markdown]
# ## 2c

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02

# %%
Repayment["Month"] = pd.to_datetime(Repayment["Month"])
# Out:
# C:\Users\rhythm\AppData\Local\Temp\ipykernel_6296\2332901548.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Repayment["Month"] = pd.to_datetime(Repayment["Month"])

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount
# 0       A1 2004-01-12  495414.75
# 1       A1 2004-01-03  245899.02

# %%
Repayment.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Amount             float64
# dtype: object

# %%
Repayment['Monthly'] = Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Repayment['Yearly'] = Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
Repayment.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Amount             float64
# Monthly             object
# Yearly              object
# dtype: object

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount  Monthly Yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004

# %%
cust_repay1= Repayment.pivot_table(index=['Yearly','Monthly'],values='Amount',aggfunc= 'mean').round(2).reset_index()

# %%
cust_repay1
# Out:
#    Yearly    Monthly     Amount
# 0    2004      April  259141.68
# 1    2004   February  256702.63
# 2    2004    January  243489.65
# 3    2004      March  252585.28
# 4    2004        May  226162.72
# 5    2004   November  209592.24
# 6    2004  September  184487.85
# 7    2005      April  212688.63
# 8    2005     August  264430.92
# 9    2005   December  320379.34
# 10   2005   February  238829.27
# 11   2005    January  240548.10
# 12   2005       July  239871.48
# 13   2005       June  210199.82
# 14   2005        May  263207.37
# 15   2005   November  256695.12
# 16   2005    October  219849.96
# 17   2005  September  247700.17
# 18   2006      April  275472.25
# 19   2006     August  224143.99
# 20   2006   December  252736.57
# 21   2006   February  284489.57
# 22   2006    January  293475.39
# 23   2006       July  257936.38
# 24   2006       June  251990.45
# 25   2006      March  240851.27
# 26   2006        May  256920.88
# 27   2006   November  199399.20
# ...

# %% [markdown]
# ## 2e

# %%
cust_spend_repay = pd.merge(left=Spend,right=Repayment,on="Customer",how="inner")

# %%
cust_spend_repay.head(2)
# Out:
#    Sl No: Customer    Month_x       Type  Amount_x Monthly_x Yearly_x  \
# 0       1       A1 2004-01-12  JEWELLERY  485470.8   January     2004
# 1       1       A1 2004-01-12  JEWELLERY  485470.8   January     2004
#
#      Month_y   Amount_y Monthly_y Yearly_y
# 0 2004-01-12  495414.75   January     2004
# 1 2004-01-03  245899.02   January     2004

# %%
interest = cust_spend_repay.groupby(["Yearly_y","Monthly_y"])[['Amount_x','Amount_y']].sum()

# %%
interest
# Out:
#                         Amount_x      Amount_y
# Yearly_y Monthly_y
# 2004     April      2.108042e+08  2.285403e+08
#          February   1.562344e+08  1.602419e+08
#          January    1.715187e+09  1.699210e+09
#          March      8.258765e+07  8.974470e+07
#          May        1.526538e+08  1.411594e+08
#          November   9.226463e+07  7.860290e+07
#          September  9.702432e+07  8.016122e+07
# 2005     April      2.018261e+08  1.747894e+08
#          August     2.345989e+08  2.477449e+08
#          December   7.186922e+07  9.944533e+07
#          February   9.701575e+08  9.416163e+08
#          January    1.766266e+08  1.810333e+08
#          July       8.534751e+07  7.997268e+07
#          June       2.570007e+08  2.213774e+08
#          May        9.714766e+08  1.099197e+09
#          November   2.611733e+08  2.763119e+08
#          October    6.731423e+07  6.027830e+07
#          September  7.650695e+07  7.530449e+07
# ...

# %%
interest['Monthly Profit'] = interest['Amount_y'] - interest['Amount_x']

# %%
interest.head(2)
# Out:
#                         Amount_x      Amount_y  Monthly Profit
# Yearly_y Monthly_y
# 2004     April      2.108042e+08  2.285403e+08     17736030.58
#          February   1.562344e+08  1.602419e+08      4007528.32

# %%
interest.dtypes
# Out:
# Amount_x          float64
# Amount_y          float64
# Monthly Profit    float64
# dtype: object

# %%
interest['Monthly Profit']=interest['Monthly Profit'].astype('int64')

# %%
interest.dtypes
# Out:
# Amount_x          float64
# Amount_y          float64
# Monthly Profit      int64
# dtype: object

# %%
interest['Int_Earned'] = (2.9* interest['Monthly Profit'])/100

# %%
interest.head(2)
# Out:
#                         Amount_x      Amount_y  Monthly Profit  Int_Earned
# Yearly_y Monthly_y
# 2004     April      2.108042e+08  2.285403e+08        17736030  514344.870
#          February   1.562344e+08  1.602419e+08         4007528  116218.312

# %% [markdown]
# # 2f

# %%
Spend.head(5)
# Out:
#    Sl No: Customer      Month       Type     Amount  Monthly Yearly
# 0       1       A1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       2       A1 2004-01-03      PETRO  410556.13  January   2004
# 2       3       A1 2004-01-15    CLOTHES   23740.46  January   2004
# 3       4       A1 2004-01-25       FOOD  484342.47  January   2004
# 4       5       A1 2005-01-17     CAMERA  369694.07  January   2005

# %%
Spend['Type'].value_counts().head()
# Out:
# Type
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: count, dtype: int64

# %%
plt.figure(figsize= (3,2))
Spend['Type'].value_counts().head(5).plot(kind='barh')
plt.title("graphical representation of the top 5 product types on which customer spent")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2g

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount
# 0       1  12-Jan-04  JEWELLERY  485470.80
# 1       2   3-Jan-04      PETRO  410556.13
# 2       3  15-Jan-04    CLOTHES   23740.46
# 3       4  25-Jan-04       FOOD  484342.47
# 4       5  17-Jan-05     CAMERA  369694.07

# %%
city_maxspend = cust_spend.groupby("City")["Amount"].sum().sort_values(ascending=False)

# %%
city_maxspend
# Out:
# City
# COCHIN        45963513.50
# CALCUTTA      41108132.30
# BANGALORE     40461647.02
# BOMBAY        28603127.38
# CHENNAI       22128635.65
# TRIVANDRUM    15337155.87
# PATNA         15260586.97
# DELHI         10918286.54
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(5,3))
city_maxspend.plot(kind="pie")
plt.title("Amount spent on credit card by customers from different cities")
plt.show()
print('cochin is the following city having maximum spend')
# Out:
# cochin is the following city having maximum spend

# %% [markdown]
# # 2g

# %%
cust_spend["Age Group"] =  pd.cut(cust_spend["Age"],bins=np.arange(18,88,8),labels=["18-26","26-34", "34-42" ,"42-50" ,"50-58","58-66","66-74","74-82"],include_lowest=True)

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age Group
# 0       1  12-Jan-04  JEWELLERY  485470.80     74-82
# 1       2   3-Jan-04      PETRO  410556.13     74-82
# 2       3  15-Jan-04    CLOTHES   23740.46     74-82
# 3       4  25-Jan-04       FOOD  484342.47     74-82
# 4       5  17-Jan-05     CAMERA  369694.07     74-82

# %%
agegrp_spend = cust_spend.groupby("Age Group")['Amount'].sum().sort_values(ascending=False)

# %%
agegrp_spend
# Out:
# Age Group
# 42-50    53242390.70
# 34-42    38037826.50
# 26-34    30553459.81
# 18-26    25233896.65
# 50-58    22454066.68
# 74-82    19770884.32
# 66-74    17705877.44
# 58-66    12782683.13
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(5,5))
agegrp_spend.plot(kind = "barh",stacked=True)
plt.show()
print("From the horizontal bar chart we can say that age group 42 - 50 is spending more money")
# Out:
# From the horizontal bar chart we can say that age group 42 - 50 is spending more money

# %% [markdown]
# # 2i

# %%
cust_repay.head()
# Out:
#   Customer      Month     Amount  No   Age       City Product     Limit  \
# 0       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold  500000.0
# 1       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold  500000.0
# 2       A1  15-Jan-04  259490.06   1  76.0  BANGALORE    Gold  500000.0
# 3       A1  25-Jan-04  437555.12   1  76.0  BANGALORE    Gold  500000.0
# 4       A1  17-Jan-05  165972.88   1  76.0  BANGALORE    Gold  500000.0
#
#   Company        Segment
# 0      C1  Self Employed
# 1      C1  Self Employed
# 2      C1  Self Employed
# 3      C1  Self Employed
# 4      C1  Self Employed

# %%
cust_repay.groupby("Customer")[["Amount"]].sum().sort_values(by="Amount",ascending=False).head(10).reset_index()
# Out:
#   Customer       Amount
# 0      A61  10539142.91
# 1      A60   9876290.74
# 2      A13   9572000.66
# 3      A43   8489871.46
# 4      A45   8448334.87
# 5      A12   8334760.16
# 6      A14   7943268.63
# 7      A44   7744730.12
# 8      A39   7622483.30
# 9      A42   7615460.86

# %% [markdown]
# # 3

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age Group
# 0       1  12-Jan-04  JEWELLERY  485470.80     74-82
# 1       2   3-Jan-04      PETRO  410556.13     74-82
# 2       3  15-Jan-04    CLOTHES   23740.46     74-82
# 3       4  25-Jan-04       FOOD  484342.47     74-82
# 4       5  17-Jan-05     CAMERA  369694.07     74-82

# %%
cust_spend.dtypes
# Out:
# No              int64
# Customer       object
# Age           float64
# City           object
# Product        object
# Limit         float64
# Company        object
# Segment        object
# Sl No:          int64
# Month          object
# Type           object
# Amount        float64
# Age Group    category
# dtype: object

# %%
cust_spend["Month"] = pd.to_datetime(cust_spend["Month"])
# Out:
# C:\Users\rhythm\AppData\Local\Temp\ipykernel_6296\2972196490.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cust_spend["Month"] = pd.to_datetime(cust_spend["Month"])

# %%
cust_spend['Year'] = cust_spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
cust_spend.head(2)
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age Group  Year
# 0       1 2004-01-12  JEWELLERY  485470.80     74-82  2004
# 1       2 2004-01-03      PETRO  410556.13     74-82  2004

# %%
cust_spend_pivot = pd.pivot_table(data = cust_spend,index=["City","Year"],columns='Product',aggfunc="sum",values="Amount")

# %%
cust_spend_pivot.reset_index()
# Out:
# Product        City  Year         Gold    Platimum      Silver
# 0         BANGALORE  2004   9289878.54  1112732.30  1291852.58
# 1         BANGALORE  2005  12892362.99   912284.97   830612.34
# 2         BANGALORE  2006  12030611.09   685831.27  1415480.94
# 3            BOMBAY  2004   6987853.53   897264.94   532089.03
# 4            BOMBAY  2005   8983018.28   711804.94   508988.54
# 5            BOMBAY  2006   7917144.31   972130.01  1092833.80
# 6          CALCUTTA  2004   7477140.98  2037690.30   500006.00
# 7          CALCUTTA  2005  10303355.80  4434696.31   440147.06
# 8          CALCUTTA  2006  11167532.77  3589606.66  1157956.42
# 9           CHENNAI  2004   1059618.50  3535652.38   282056.86
# 10          CHENNAI  2005   3740945.58  5053956.32   377184.49
# 11          CHENNAI  2006   2704288.62  5024923.40   350009.50
# 12           COCHIN  2004   7315850.15  3419904.07   814229.62
# 13           COCHIN  2005  12110613.03  4960921.71   652269.38
# ...

# %%
cust_spend_pivot.plot(kind="bar",figsize=(8,5))
plt.ylabel("Amount_x")
plt.title("Amount spended by customers according to year and city")
plt.show()

# %% [markdown]
# # 4a

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age Group  Year
# 0       1 2004-01-12  JEWELLERY  485470.80     74-82  2004
# 1       2 2004-01-03      PETRO  410556.13     74-82  2004
# 2       3 2004-01-15    CLOTHES   23740.46     74-82  2004
# 3       4 2004-01-25       FOOD  484342.47     74-82  2004
# 4       5 2005-01-17     CAMERA  369694.07     74-82  2005

# %%
cust_spend['Monthly'] = cust_spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%b"))
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age Group  Year Monthly
# 0       1 2004-01-12  JEWELLERY  485470.80     74-82  2004     Jan
# 1       2 2004-01-03      PETRO  410556.13     74-82  2004     Jan
# 2       3 2004-01-15    CLOTHES   23740.46     74-82  2004     Jan
# 3       4 2004-01-25       FOOD  484342.47     74-82  2004     Jan
# 4       5 2005-01-17     CAMERA  369694.07     74-82  2005     Jan

# %%
monthly_comp = cust_spend.groupby(["Monthly","City"])[["Amount"]].sum().sort_index().reset_index()

# %%
monthly_comp =pd.pivot_table(data=cust_spend,values='Amount',index='City',columns='Monthly',aggfunc='sum')
monthly_comp
# Out:
# Monthly            Apr         Aug        Dec         Feb          Jan  \
# City
# BANGALORE   4207980.48   695061.95  422167.24  6734494.76   9041796.84
# BOMBAY      1873785.01  1066744.75  140040.71  4276988.30   5948993.33
# CALCUTTA    3457507.95  1548354.02   55001.50  8150545.61   9064864.90
# CHENNAI     2518656.99   305875.97  223628.27  4385815.95   4466961.36
# COCHIN      3882744.94  2317306.61  909533.05  5747886.38  11714373.54
# DELHI        777240.75   155402.16  842342.02  1494064.06   2714261.45
# PATNA       2338179.53   419383.64   50000.00  2353333.55   4916205.55
# TRIVANDRUM  1199293.45   453773.94  640922.26  2857123.89   3704336.99
#
# Monthly            Jul         Jun         Mar         May         Nov  \
# City
# BANGALORE   2228217.69  1330685.90  5362903.07  6383115.13  2260603.07
# BOMBAY       177726.32  1172594.97  5227850.50  3891945.60  2872049.40
# CALCUTTA    2234573.27  2293045.81  4939040.04  5578246.87  2078880.93
# ...

# %%
monthly_comp.plot(kind="bar",figsize=(18,6))
plt.title('Graphical representation of Monthly comparison of total spends city wise')
plt.show()

# %% [markdown]
# # 4b

# %%
air_tickets = cust_spend.groupby(["Year","Type"])[["Amount"]].sum().reset_index()

# %%
air_tickets1 = air_tickets.loc[air_tickets["Type"]=="AIR TICKET"]

# %%
air_tickets1
# Out:
#     Year        Type       Amount
# 0   2004  AIR TICKET   4357225.35
# 15  2005  AIR TICKET  10550152.21
# 30  2006  AIR TICKET   5248469.56

# %%
plt.bar(air_tickets1["Year"],height=air_tickets1["Amount"],color="orange")
plt.xlabel("Year")
plt.ylabel("Amount Spent")
plt.title("Comparison of yearly spend on air tickets")
plt.show()

# %% [markdown]
# # 4c

# %%
product_comp= pd.pivot_table(data=cust_spend,index='Product',columns='Monthly',values='Amount',aggfunc='sum')

# %%
product_comp
# Out:
# Monthly           Apr         Aug         Dec          Feb          Jan  \
# Product
# Gold      13170572.59  4954030.42  2332940.96  24779179.55  32413831.83
# Platimum   5182493.86  1714762.80   750156.19   9134054.58  14951578.51
# Silver     1902322.65   293109.82   200537.90   2087018.37   4206383.62
#
# Monthly          Jul         Jun          Mar          May         Nov  \
# Product
# Gold      5167416.37  6538862.64  19256972.48  21548169.76  9203267.46
# Platimum  1288156.26  2965712.71   7288837.68   8151926.49  2741618.42
# Silver     530153.72   689537.61   3909405.83   2140940.01   691102.63
#
# Monthly          Oct         Sep
# Product
# Gold      3018223.38  3816887.62
# Platimum   550275.04  1667840.84
# Silver     100001.50   442803.13

# %%
product_comp.plot(kind="bar",figsize=(10,5))
plt.ylabel("Amount_x")
plt.title("Amount spent monthly on different products")
plt.show()
print("highest sales are in January")
# Out:
# highest sales are in January

# %% [markdown]
# # 5

# %%
cust_repay.head(2)
# Out:
#   Customer      Month     Amount  No   Age       City Product     Limit  \
# 0       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold  500000.0
# 1       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold  500000.0
#
#   Company        Segment
# 0      C1  Self Employed
# 1      C1  Self Employed

# %%
cust_repay['Month'] = pd.to_datetime(cust_repay['Month'])
# Out:
# C:\Users\rhythm\AppData\Local\Temp\ipykernel_6296\214662920.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cust_repay['Month'] = pd.to_datetime(cust_repay['Month'])

# %%
cust_repay['Monthly'] = cust_repay['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
cust_repay['Yearly'] = cust_repay['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
def summary_report(product,timeperiod):
    print('Give the product name and timeperiod for which you want the data')
    if product.lower()=='gold' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='gold' and timeperiod.lower()=='yearly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='yearly':
        pivot= cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    if product.lower()=='platinum' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='platinum' and timeperiod.lower()=='yearly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    return result

# %%
summary_report('silver','yearly').head(10)
# Out:
# Give the product name and timeperiod for which you want the data
# Yearly                           2004        2005        2006
# Product City      Customer
# Silver  BANGALORE A18       491592.71   638296.41   700000.00
#                   A23       664965.71  1000010.00   872925.32
#                   A59       676557.50   427247.08   600018.00
#                   A72       100000.00         NaN         NaN
#                   A76             NaN   265619.05         NaN
#                   A77             NaN         NaN     3159.62
#         COCHIN    A100       69551.19         NaN         NaN
#                   A25       786338.08   611555.69  1000030.00
#                   A7        500005.00   422177.27   608997.87
#                   A74             NaN   100002.00         NaN

# %% [markdown]
# # finish
